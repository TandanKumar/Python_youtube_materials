# %% [markdown]
# # Python

# %% [markdown]
# Python is a high level general purpose programming language.
# It is also object oriented programming and scripting language

# %% [markdown]
# ## Reason for demand of Python
#
# ![python.png](attachment:python.png)
#
# Imgae:- Google source

# %% [markdown]
# How to install python in our system:-
#
# To download Python, you need to visit [www.python.org](www.python.org) which is the official Python website.
#
# After opening the given link it will show the  below pic.
#
# ![python_installer.png](attachment:python_installer.png)
#
#
# From the above pic, need to download the installer.

# %% [markdown]
# Python IDE
#     Jupyter Notebook
#     vs code
#     pycharm

# %% [markdown]
# Anaconda - Anaconda Python is a free, open-source platform that allows you to write and
# execute code in the programming language Python
#
# How to install Anaconda - https://docs.anaconda.com/free/anaconda/install/windows/
